# %% [markdown]
# ### Machine Learning: Summer 2020
# ### Project 3
#
# # Image Classification using Tensorflow
#
# ### Anshul Dabas and Anndi Russell

# %% [markdown]
# ## Experiment Objective

# %% [markdown]
# In this project, we are attempting to classify an image as either a car or a plane. We downloaded the dataset from [geeksforgeeks.org](https://www.geeksforgeeks.org/python-image-classification-using-keras/); the dataset is publically available and contains no sensitive, personal information that could be of ethical concern.
#
# The original data was split into training and test directories, and further into cars and planes directories. This will allow us to label the images appropriately as either a car or a plane.
#
# Our goal is that, given an image of a car or a plane, our model can accurately predict which one it is. This research could be used in a ReCaptcha to verify that you're not a robot (i.e. "Click all the images that have planes in them").

# %% [markdown]
# ## Data Collection and Preprocessing

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import pathlib
import glob
from PIL import Image

# %% [markdown]
# ##### First, we will import data and display some information and images, as well as explain each step. Then, we will wrap all of these steps in a function that will be used later.

# %% [markdown]
# Create paths for the cars and planes directories within the training and testing directories:

# %%
train_planes_path = pathlib.Path('v_data/train/planes')
train_cars_path = pathlib.Path('v_data/train/cars')

test_planes_path = pathlib.Path('v_data/test/planes')
test_cars_path = pathlib.Path('v_data/test/cars')

# %% [markdown]
# Make a list of the .jpg files in each directory:

# %%
train_planes_file_list = sorted([str(path) for path in train_planes_path.glob('*.jpg')])
train_cars_file_list = sorted([str(path) for path in train_cars_path.glob('*.jpg')])

test_planes_file_list = sorted([str(path) for path in test_planes_path.glob('*.jpg')])
test_cars_file_list = sorted([str(path) for path in test_cars_path.glob('*.jpg')])

# %% [markdown]
# Display the lengths of the files lists for each directory:

# %%
print("Training planes: ",len(train_planes_file_list))
print("Training cars: ",len(train_cars_file_list))
print("Testing planes: ",len(test_planes_file_list))
print("Testing cars: ",len(test_cars_file_list))
# Out:
# Training planes:  200
# Training cars:  200
# Testing planes:  50
# Testing cars:  50

# %% [markdown]
# Shape and display of a sample of 6 planes images:

# %%
fig = plt.figure(figsize=(10, 5))
i=0
for i,file in enumerate(train_planes_file_list):
    img_raw = tf.io.read_file(file)
    img = tf.image.decode_image(img_raw)
    print('Image shape: ', img.shape)
    ax = fig.add_subplot(2, 3, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(img)
    ax.set_title(os.path.basename(file), size=15)
    i=i+1
    if i==6:
        break
# plt.savefig('ch13-catdot-examples.pdf')
plt.tight_layout()
plt.show()
# Out:
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)

# %% [markdown]
# Shape and display of a sample of 6 cars images:

# %%
fig = plt.figure(figsize=(10, 5))
i=0
for i,file in enumerate(train_cars_file_list):
    img_raw = tf.io.read_file(file)
    img = tf.image.decode_image(img_raw)
    print('Image shape: ', img.shape)
    ax = fig.add_subplot(2, 3, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(img)
    ax.set_title(os.path.basename(file), size=15)
    i=i+1
    if i==6:
        break
# plt.savefig('ch13-catdot-examples.pdf')
plt.tight_layout()
plt.show()
# Out:
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)
# Image shape:  (224, 224, 3)

# %% [markdown]
# As we can see above, the images vary in composition, angle, and content. There also is a consistent shape for the images.

# %% [markdown]
# Create a list of labels: 1 for planes, 0 for cars:

# %%
train_planes_labels = [1 for file in train_planes_file_list]
train_cars_labels = [0 for file in train_cars_file_list]

test_planes_labels = [1 for file in test_planes_file_list]
test_cars_labels = [0 for file in test_cars_file_list]

# %% [markdown]
# Combine planes and cars files and labels for testing and training:

# %%
train_all_files=train_planes_file_list+train_cars_file_list
train_all_labels=train_planes_labels+train_cars_labels

test_all_files=test_planes_file_list+test_cars_file_list
test_all_labels=test_planes_labels+test_cars_labels

# %% [markdown]
# ##### Define functions to do the data input that we did above, and decode the images. This create_train_data function will be called by input_fn with the estimator in a future step.

# %% [markdown]
# Function to decode images:

# %%
def load_and_preprocess(paths):
    images=[]
    for path in paths:
        image=tf.io.read_file(path)
        image=tf.image.decode_jpeg(image,channels=3)
        image=tf.image.resize(image,[224,224])
        image/=255.0
        images.append(image)
    return images

# %% [markdown]
# Function to load training data and return tensorflow dataset with decoded images to the estimator:

# %%
def create_train_data():
    #returns dataset of decoded images and their labels
    
    train_planes_path = pathlib.Path('v_data/train/planes')
    train_cars_path = pathlib.Path('v_data/train/cars')
    
    train_planes_file_list = sorted([str(path) for path in train_planes_path.glob('*.jpg')])
    train_cars_file_list = sorted([str(path) for path in train_cars_path.glob('*.jpg')])
    
    train_planes_labels = [1 for file in train_planes_file_list]
    train_cars_labels = [0 for file in train_cars_file_list]
    
    train_all_files=train_planes_file_list+train_cars_file_list
    train_all_labels=train_planes_labels+train_cars_labels
    
    train_all_images=load_and_preprocess(train_all_files) #decode the images
    train_all_labels=np.array(train_all_labels)
    
    ds_images_labels = tf.data.Dataset.from_tensor_slices(
        ({'input-features':train_all_images}, train_all_labels.reshape(-1, 1)))

    ds_images_labels=ds_images_labels.shuffle(buffer_size=len(train_all_labels))
    
    #print("TRAINING DATASET:",ds_images_labels)
    return ds_images_labels

# %% [markdown]
# Function to load validation data and return tensorflow dataset:

# %%
def create_valid_data():
    valid_planes_path = pathlib.Path('v_data/test/planes')
    valid_cars_path = pathlib.Path('v_data/test/cars')
    
    valid_planes_file_list = sorted([str(path) for path in valid_planes_path.glob('*.jpg')])
    valid_cars_file_list = sorted([str(path) for path in valid_cars_path.glob('*.jpg')])
    
    valid_planes_labels = [1 for file in valid_planes_file_list]
    valid_cars_labels = [0 for file in valid_cars_file_list]
    
    valid_all_files=valid_planes_file_list+valid_cars_file_list
    valid_all_labels=valid_planes_labels+valid_cars_labels
    
    valid_all_images=load_and_preprocess(valid_all_files)
    valid_all_labels=np.array(valid_all_labels)
    
    ds_images_labels_valid = tf.data.Dataset.from_tensor_slices(
        ({'input-features':valid_all_images}, valid_all_labels.reshape(-1, 1)))

    ds_images_labels_valid=ds_images_labels_valid.shuffle(buffer_size=len(valid_all_labels))
    
    #print("VALID DATASET:",ds_images_labels_valid)
    return ds_images_labels_valid

# %% [markdown]
# ## Tensorflow Model Creation

# %% [markdown]
# Build model:

# %%
model = tf.keras.Sequential([
    
    tf.keras.layers.Input(shape=(224,224,3), name='input-features'),
    
    tf.keras.layers.Dense(units=8,
                          activation='relu',
                          kernel_initializer=tf.keras.initializers.GlorotNormal(),
                          bias_initializer=tf.keras.initializers.Constant(0.1),
                          name='hiddenlayer1'),
    tf.keras.layers.Dropout(rate=0.5),
    
    tf.keras.layers.Dense(units=8, 
                          activation='relu', 
                          name='hiddenlayer2',
                          kernel_initializer=tf.keras.initializers.GlorotNormal(),
                          bias_initializer=tf.keras.initializers.Constant(0.1)),
    
    tf.keras.layers.Dropout(rate=0.5),
    
    tf.keras.layers.Dense(units=8, 
                          activation='relu', 
                          name='hiddenlayer3',
                          kernel_initializer=tf.keras.initializers.GlorotNormal(),
                          bias_initializer=tf.keras.initializers.Constant(0.1)),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(1, 
                          activation='sigmoid', 
                          activity_regularizer='l1', name="output")
    
])

model.build(input_shape=(224,224,3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hiddenlayer1 (Dense)         (None, 224, 224, 8)       32
# _________________________________________________________________
# dropout (Dropout)            (None, 224, 224, 8)       0
# _________________________________________________________________
# hiddenlayer2 (Dense)         (None, 224, 224, 8)       72
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224, 224, 8)       0
# _________________________________________________________________
# hiddenlayer3 (Dense)         (None, 224, 224, 8)       72
# _________________________________________________________________
# flatten (Flatten)            (None, 401408)            0
# _________________________________________________________________
# output (Dense)               (None, 1)                 401409
# =================================================================
# Total params: 401,585
# Trainable params: 401,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Configure model:

# %%
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(), 
             tf.keras.metrics.Precision(),
             tf.keras.metrics.Recall(),])

# %% [markdown]
# Define the feature columns:

# %%
features = [
    tf.feature_column.numeric_column(
        key='input-features:', shape=(224,224,3))
]
    
features
# Out:
# [NumericColumn(key='input-features:', shape=(224, 224, 3), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# #### Discussion of chosen parameters:
#
# ##### Configuring layers:
# Activations: For the dense hidden layers we are using ReLU as the activation function. This increases efficiency of runtime, and also helps avoid the problem of vanishing gradients. We are using sigmoid for the output layer; this is a good idea because our final output will be in the range [0,1], and can be interpreted as the probability of a positive ('1') outcome.
# <br>
#
# Initializers:
# In the layers that use ReLU as the activation function, we will initialize with a slightly positive bias so we can avoid dead neurons (citation [here](https://stackoverflow.com/questions/40708169/how-to-initialize-biases-in-a-keras-model)). In these same layers, we'll initialize weights using GlorotNormal; this will break symmetry between hidden units in the same layer (cititaion [here](https://stats.stackexchange.com/questions/47590/what-are-good-initial-weights-in-a-neural-network)).
#
# <br>
# Regularizers: We have the choice of L1 or L2 regularization when building our layers. We chose L1 in the sigmoid layer because it facilitaties compression of the model since some weights will decay to zero. We tried using L2 and our accuracy was lower (0.47); L1 was the better choice for accuracy.
#
# <br>
#
# ##### Compiling the model:
#
# Optimizers: We used SGD for the optimizer. We tested a few different learning rates, and 0.001 performed the best.
# <br>
# Loss functions: Binary cross entropy since we have binary output.
# <br>
# Metrics: Accuracy, precision, and recall will give us a variety of metrics to interprete, relating to both type-1 and type-2 errors.
# <br>
#
#
# ##### Dimensions of model:
#
# We tested 1, 2, and 3 hidden layers, and 3 hidden layers improved the accuracy of our model. We have 8 nodes in each layer.

# %% [markdown]
# ## TensorFlow estimator creation and training

# %% [markdown]
# Create estimator:

# %%
my_estimator = tf.keras.estimator.model_to_estimator(
    keras_model=model,
    model_dir='testmodels/est3/')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/keras.py:220: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# INFO:tensorflow:Using config: {'_model_dir': 'testmodels/est3/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# Define the input function:

# %%
num_epochs = 200
batch_size = 2
steps_per_epoch = np.ceil(400 / batch_size)

def input_fn(batch_size=8):
    ds=create_train_data()
    return ds.shuffle(100).repeat().batch(batch_size)

def eval_input_fn(batch_size=8):
    ds=create_valid_data()
    ds= ds.shuffle(100).batch(batch_size)
    return ds

# %% [markdown]
# Train the estimator:

# %%
my_estimator.train(
    input_fn=lambda: input_fn(batch_size),steps=num_epochs * steps_per_epoch)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='testmodels/est3/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: testmodels/est3/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 8 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into testmodels/est3/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.79605347, step = 0
# INFO:tensorflow:global_step/sec: 40.8851
# INFO:tensorflow:loss = 1.0694311, step = 100 (2.448 sec)
# INFO:tensorflow:global_step/sec: 41.7623
# INFO:tensorflow:loss = 0.7896401, step = 200 (2.395 sec)
# INFO:tensorflow:global_step/sec: 43.7803
# INFO:tensorflow:loss = 0.51941, step = 300 (2.284 sec)
# INFO:tensorflow:global_step/sec: 45.2308
# INFO:tensorflow:loss = 0.28244278, step = 400 (2.211 sec)
# INFO:tensorflow:global_step/sec: 45.8655
# INFO:tensorflow:loss = 0.8451875, step = 500 (2.180 sec)
# INFO:tensorflow:global_step/sec: 45.2355
# INFO:tensorflow:loss = 0.09414778, step = 600 (2.211 sec)
# INFO:tensorflow:global_step/sec: 46.1841
# INFO:tensorflow:loss = 0.36048383, step = 700 (2.165 sec)
# INFO:tensorflow:global_step/sec: 45.9499
# INFO:tensorflow:loss = 0.24952962, step = 800 (2.176 sec)
# INFO:tensorflow:global_step/sec: 45.342
# INFO:tensorflow:loss = 0.31821612, step = 900 (2.205 sec)
# INFO:tensorflow:global_step/sec: 44.1675
# INFO:tensorflow:loss = 0.051839583, step = 1000 (2.265 sec)
# INFO:tensorflow:global_step/sec: 45.6709
# INFO:tensorflow:loss = 0.16702068, step = 1100 (2.190 sec)
# INFO:tensorflow:global_step/sec: 44.7269
# INFO:tensorflow:loss = 0.05932487, step = 1200 (2.236 sec)
# INFO:tensorflow:global_step/sec: 45.1815
# INFO:tensorflow:loss = 0.23630358, step = 1300 (2.214 sec)
# INFO:tensorflow:global_step/sec: 44.3562
# INFO:tensorflow:loss = 0.2424839, step = 1400 (2.254 sec)
# INFO:tensorflow:global_step/sec: 42.5529
# INFO:tensorflow:loss = 0.6010669, step = 1500 (2.350 sec)
# INFO:tensorflow:global_step/sec: 44.7926
# INFO:tensorflow:loss = 0.3000301, step = 1600 (2.235 sec)
# INFO:tensorflow:global_step/sec: 47.2688
# INFO:tensorflow:loss = 0.016505461, step = 1700 (2.114 sec)
# INFO:tensorflow:global_step/sec: 43.6955
# INFO:tensorflow:loss = 0.19026788, step = 1800 (2.289 sec)
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: testmodels/est3/model.ckpt-40000
# {'binary_accuracy': 0.83,
#  'loss': 0.9647092,
#  'precision': 0.8367347,
#  'recall': 0.82,
#  'global_step': 40000}

# %% [markdown]
# Create new function to load the data, this time returning x and y as numpy arrays. This will be used in model.fit():

# %%
def create_train_data_separate():
    #returns arrays of decoded images and their labels
    
    train_planes_path = pathlib.Path('v_data/train/planes')
    train_cars_path = pathlib.Path('v_data/train/cars')
    
    train_planes_file_list = sorted([str(path) for path in train_planes_path.glob('*.jpg')])
    train_cars_file_list = sorted([str(path) for path in train_cars_path.glob('*.jpg')])
    
    train_planes_labels = [1 for file in train_planes_file_list]
    train_cars_labels = [0 for file in train_cars_file_list]
    
    train_all_files=train_planes_file_list+train_cars_file_list
    train_all_labels=train_planes_labels+train_cars_labels
    
    train_all_images=load_and_preprocess(train_all_files) #decode the images
    train_all_labels=np.array(train_all_labels)
    
    x_train=train_all_images
    y_train=train_all_labels
    
    return x_train, y_train

# %%
def create_valid_data_separate():
    valid_planes_path = pathlib.Path('v_data/test/planes')
    valid_cars_path = pathlib.Path('v_data/test/cars')
    
    valid_planes_file_list = sorted([str(path) for path in valid_planes_path.glob('*.jpg')])
    valid_cars_file_list = sorted([str(path) for path in valid_cars_path.glob('*.jpg')])
    
    valid_planes_labels = [1 for file in valid_planes_file_list]
    valid_cars_labels = [0 for file in valid_cars_file_list]
    
    valid_all_files=valid_planes_file_list+valid_cars_file_list
    valid_all_labels=valid_planes_labels+valid_cars_labels
    
    valid_all_images=load_and_preprocess(valid_all_files)
    valid_all_labels=np.array(valid_all_labels)
    
    x_valid=valid_all_images
    y_valid=valid_all_labels
    
    return x_valid, y_valid

# %%
x_train, y_train=create_train_data_separate()
x_valid, y_valid=create_valid_data_separate()
x_train= np.stack( x_train, axis=0 ) #stack into single np array
x_valid= np.stack( x_valid, axis=0 )

# %% [markdown]
# Redefine the model for use in model.fit():

# %%
model = tf.keras.Sequential([
    
    tf.keras.layers.Input(shape=(224,224,3), name='input-features'),
    
    tf.keras.layers.Dense(units=8,
                          activation='relu',
                          kernel_initializer=tf.keras.initializers.GlorotNormal(),
                          bias_initializer=tf.keras.initializers.Constant(0.1),
                          name='hiddenlayer1'),
    tf.keras.layers.Dropout(rate=0.5),
    
    tf.keras.layers.Dense(units=8, 
                          activation='relu', 
                          name='hiddenlayer2',
                          kernel_initializer=tf.keras.initializers.GlorotNormal(),
                          bias_initializer=tf.keras.initializers.Constant(0.1)),
    
    tf.keras.layers.Dropout(rate=0.5),
    
    tf.keras.layers.Dense(units=8, 
                          activation='relu', 
                          name='hiddenlayer3',
                          kernel_initializer=tf.keras.initializers.GlorotNormal(),
                          bias_initializer=tf.keras.initializers.Constant(0.1)),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(1, 
                          activation='sigmoid', 
                          activity_regularizer='l1', name="output")
    
])

model.build(input_shape=(224,224,3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hiddenlayer1 (Dense)         (None, 224, 224, 8)       32
# _________________________________________________________________
# dropout (Dropout)            (None, 224, 224, 8)       0
# _________________________________________________________________
# hiddenlayer2 (Dense)         (None, 224, 224, 8)       72
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224, 224, 8)       0
# _________________________________________________________________
# hiddenlayer3 (Dense)         (None, 224, 224, 8)       72
# _________________________________________________________________
# flatten (Flatten)            (None, 401408)            0
# _________________________________________________________________
# output (Dense)               (None, 1)                 401409
# =================================================================
# Total params: 401,585
# Trainable params: 401,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile model:

# %%
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(), 
             tf.keras.metrics.Precision(),
             tf.keras.metrics.Recall(),])

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
x_train.shape
# Out:
# (400, 224, 224, 3)

# %%
y_train.shape
# Out:
# (400,)

# %% [markdown]
# Fit the model and store the history:

# %%
hist = model.fit(x_train, y_train, 
                 validation_data=(x_valid, y_valid), 
                 epochs=200, batch_size=2, verbose=1)
# Out:
# Epoch 1/200
# 200/200 [==============================] - 6s 30ms/step - loss: 1.1785 - binary_accuracy: 0.6275 - precision: 0.6220 - recall: 0.6500 - val_loss: 0.6102 - val_binary_accuracy: 0.7800 - val_precision: 0.7000 - val_recall: 0.9800
# Epoch 2/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.4839 - binary_accuracy: 0.7675 - precision: 0.7610 - recall: 0.7800 - val_loss: 0.4743 - val_binary_accuracy: 0.8300 - val_precision: 0.8511 - val_recall: 0.8000
# Epoch 3/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.4331 - binary_accuracy: 0.8200 - precision: 0.8077 - recall: 0.8400 - val_loss: 0.4547 - val_binary_accuracy: 0.8200 - val_precision: 0.7759 - val_recall: 0.9000
# Epoch 4/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.3741 - binary_accuracy: 0.8450 - precision: 0.8350 - recall: 0.8600 - val_loss: 0.4279 - val_binary_accuracy: 0.8800 - val_precision: 0.8519 - val_recall: 0.9200
# Epoch 5/200
# 200/200 [==============================] - 6s 31ms/step - loss: 0.3694 - binary_accuracy: 0.8475 - precision: 0.8233 - recall: 0.8850 - val_loss: 0.4134 - val_binary_accuracy: 0.8600 - val_precision: 0.9286 - val_recall: 0.7800
# Epoch 6/200
# 200/200 [==============================] - 6s 30ms/step - loss: 0.3035 - binary_accuracy: 0.8850 - precision: 0.8775 - recall: 0.8950 - val_loss: 0.3888 - val_binary_accuracy: 0.8700 - val_precision: 0.8776 - val_recall: 0.8600
# Epoch 7/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.3039 - binary_accuracy: 0.8825 - precision: 0.8806 - recall: 0.8850 - val_loss: 0.3711 - val_binary_accuracy: 0.8800 - val_precision: 0.9130 - val_recall: 0.8400
# Epoch 8/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.2694 - binary_accuracy: 0.8975 - precision: 0.8916 - recall: 0.9050 - val_loss: 0.3828 - val_binary_accuracy: 0.8500 - val_precision: 0.9487 - val_recall: 0.7400
# Epoch 9/200
# 200/200 [==============================] - 6s 31ms/step - loss: 0.2607 - binary_accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - val_loss: 0.3448 - val_binary_accuracy: 0.8900 - val_precision: 0.9149 - val_recall: 0.8600
# Epoch 10/200
# 200/200 [==============================] - 6s 31ms/step - loss: 0.2665 - binary_accuracy: 0.8975 - precision: 0.8916 - recall: 0.9050 - val_loss: 0.3640 - val_binary_accuracy: 0.8500 - val_precision: 0.9268 - val_recall: 0.7600
# Epoch 11/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.2061 - binary_accuracy: 0.9175 - precision: 0.9034 - recall: 0.9350 - val_loss: 0.3923 - val_binary_accuracy: 0.8400 - val_precision: 0.9722 - val_recall: 0.7000
# Epoch 12/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.2141 - binary_accuracy: 0.9175 - precision: 0.9154 - recall: 0.9200 - val_loss: 0.3338 - val_binary_accuracy: 0.8900 - val_precision: 0.9149 - val_recall: 0.8600
# Epoch 13/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.1760 - binary_accuracy: 0.9425 - precision: 0.9447 - recall: 0.9400 - val_loss: 0.3449 - val_binary_accuracy: 0.8300 - val_precision: 0.8837 - val_recall: 0.7600
# Epoch 14/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.1803 - binary_accuracy: 0.9350 - precision: 0.9307 - recall: 0.9400 - val_loss: 0.3664 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 15/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.1457 - binary_accuracy: 0.9525 - precision: 0.9502 - recall: 0.9550 - val_loss: 0.3303 - val_binary_accuracy: 0.8700 - val_precision: 0.8776 - val_recall: 0.8600
# Epoch 16/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.1484 - binary_accuracy: 0.9475 - precision: 0.9366 - recall: 0.9600 - val_loss: 0.3549 - val_binary_accuracy: 0.8500 - val_precision: 0.8723 - val_recall: 0.8200
# Epoch 17/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.1362 - binary_accuracy: 0.9650 - precision: 0.9604 - recall: 0.9700 - val_loss: 0.4241 - val_binary_accuracy: 0.8300 - val_precision: 0.9459 - val_recall: 0.7000
# Epoch 18/200
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1207 - binary_accuracy: 0.9600 - precision: 0.9554 - recall: 0.9650 - val_loss: 0.4003 - val_binary_accuracy: 0.8300 - val_precision: 0.8837 - val_recall: 0.7600
# Epoch 19/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0971 - binary_accuracy: 0.9750 - precision: 0.9703 - recall: 0.9800 - val_loss: 0.3653 - val_binary_accuracy: 0.8600 - val_precision: 0.8913 - val_recall: 0.8200
# Epoch 20/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.1185 - binary_accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - val_loss: 0.3614 - val_binary_accuracy: 0.8700 - val_precision: 0.8776 - val_recall: 0.8600
# Epoch 21/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0684 - binary_accuracy: 0.9850 - precision: 0.9802 - recall: 0.9900 - val_loss: 0.3731 - val_binary_accuracy: 0.8600 - val_precision: 0.8462 - val_recall: 0.8800
# Epoch 22/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0778 - binary_accuracy: 0.9825 - precision: 0.9801 - recall: 0.9850 - val_loss: 0.3790 - val_binary_accuracy: 0.8600 - val_precision: 0.8913 - val_recall: 0.8200
# Epoch 23/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0589 - binary_accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - val_loss: 0.4302 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 24/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0576 - binary_accuracy: 0.9875 - precision: 0.9899 - recall: 0.9850 - val_loss: 0.4214 - val_binary_accuracy: 0.8600 - val_precision: 0.8913 - val_recall: 0.8200
# Epoch 25/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0531 - binary_accuracy: 0.9925 - precision: 0.9900 - recall: 0.9950 - val_loss: 0.4233 - val_binary_accuracy: 0.8600 - val_precision: 0.8600 - val_recall: 0.8600
# Epoch 26/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0580 - binary_accuracy: 0.9825 - precision: 0.9801 - recall: 0.9850 - val_loss: 0.4511 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 27/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0391 - binary_accuracy: 0.9900 - precision: 0.9949 - recall: 0.9850 - val_loss: 0.4517 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 28/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0661 - binary_accuracy: 0.9775 - precision: 0.9751 - recall: 0.9800 - val_loss: 0.4331 - val_binary_accuracy: 0.8800 - val_precision: 0.8800 - val_recall: 0.8800
# Epoch 29/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0407 - binary_accuracy: 0.9950 - precision: 1.0000 - recall: 0.9900 - val_loss: 0.4624 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 30/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0456 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.4690 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 31/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0350 - binary_accuracy: 0.9900 - precision: 0.9900 - recall: 0.9900 - val_loss: 0.5658 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 32/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0330 - binary_accuracy: 0.9925 - precision: 0.9950 - recall: 0.9900 - val_loss: 0.6423 - val_binary_accuracy: 0.8000 - val_precision: 0.7273 - val_recall: 0.9600
# Epoch 33/200
# 200/200 [==============================] - 6s 30ms/step - loss: 0.0252 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.4996 - val_binary_accuracy: 0.8700 - val_precision: 0.8776 - val_recall: 0.8600
# Epoch 34/200
# 200/200 [==============================] - 6s 32ms/step - loss: 0.0386 - binary_accuracy: 0.9875 - precision: 0.9851 - recall: 0.9900 - val_loss: 0.5057 - val_binary_accuracy: 0.8500 - val_precision: 0.8182 - val_recall: 0.9000
# Epoch 35/200
# 200/200 [==============================] - 6s 30ms/step - loss: 0.0251 - binary_accuracy: 0.9900 - precision: 0.9900 - recall: 0.9900 - val_loss: 0.5005 - val_binary_accuracy: 0.8900 - val_precision: 0.8824 - val_recall: 0.9000
# Epoch 36/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0195 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5351 - val_binary_accuracy: 0.8600 - val_precision: 0.8333 - val_recall: 0.9000
# Epoch 37/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0145 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5364 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 38/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0173 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5217 - val_binary_accuracy: 0.8800 - val_precision: 0.8800 - val_recall: 0.8800
# Epoch 39/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0199 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.5124 - val_binary_accuracy: 0.8700 - val_precision: 0.8627 - val_recall: 0.8800
# Epoch 40/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0178 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.6144 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 41/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0124 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5588 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 42/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0192 - binary_accuracy: 0.9975 - precision: 0.9950 - recall: 1.0000 - val_loss: 0.5715 - val_binary_accuracy: 0.8600 - val_precision: 0.8333 - val_recall: 0.9000
# Epoch 43/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0538 - binary_accuracy: 0.9900 - precision: 0.9900 - recall: 0.9900 - val_loss: 0.5449 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 44/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0231 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.5366 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 45/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0135 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5511 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 46/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0169 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.6030 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 47/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0160 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7372 - val_binary_accuracy: 0.8300 - val_precision: 0.7619 - val_recall: 0.9600
# Epoch 48/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0143 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.6038 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 49/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0225 - binary_accuracy: 0.9925 - precision: 0.9900 - recall: 0.9950 - val_loss: 0.5966 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 50/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0117 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6355 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 51/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0111 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6090 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 52/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0391 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.6437 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 53/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0113 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6015 - val_binary_accuracy: 0.8800 - val_precision: 0.8800 - val_recall: 0.8800
# Epoch 54/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0150 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.6482 - val_binary_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 55/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0347 - binary_accuracy: 0.9900 - precision: 0.9949 - recall: 0.9850 - val_loss: 0.6313 - val_binary_accuracy: 0.8700 - val_precision: 0.8627 - val_recall: 0.8800
# Epoch 56/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0158 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.6282 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 57/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0113 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6561 - val_binary_accuracy: 0.8600 - val_precision: 0.8214 - val_recall: 0.9200
# Epoch 58/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0200 - binary_accuracy: 0.9925 - precision: 0.9900 - recall: 0.9950 - val_loss: 0.6360 - val_binary_accuracy: 0.8500 - val_precision: 0.8723 - val_recall: 0.8200
# Epoch 59/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0108 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6479 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 60/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0161 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.6877 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 61/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0085 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6501 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 62/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0076 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6809 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 63/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0089 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6475 - val_binary_accuracy: 0.8700 - val_precision: 0.8776 - val_recall: 0.8600
# Epoch 64/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0114 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6891 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 65/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0082 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6761 - val_binary_accuracy: 0.8800 - val_precision: 0.8519 - val_recall: 0.9200
# Epoch 66/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0103 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6918 - val_binary_accuracy: 0.8700 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 67/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0075 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6934 - val_binary_accuracy: 0.8600 - val_precision: 0.8462 - val_recall: 0.8800
# Epoch 68/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0069 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7367 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 69/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0074 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7189 - val_binary_accuracy: 0.8800 - val_precision: 0.8519 - val_recall: 0.9200
# Epoch 70/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0080 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7485 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 71/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0074 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7370 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 72/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0076 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7333 - val_binary_accuracy: 0.8800 - val_precision: 0.8519 - val_recall: 0.9200
# Epoch 73/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7615 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 74/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0068 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7553 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 75/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7525 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 76/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7709 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 77/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7949 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 78/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0067 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7770 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 79/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0065 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7965 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 80/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0067 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7822 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 81/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0068 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7937 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 82/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7796 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 83/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0060 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8051 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 84/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0270 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.8500 - val_binary_accuracy: 0.8600 - val_precision: 0.8214 - val_recall: 0.9200
# Epoch 85/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0100 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8533 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 86/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0068 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8123 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 87/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0071 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8057 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 88/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0150 - binary_accuracy: 0.9950 - precision: 0.9950 - recall: 0.9950 - val_loss: 0.8720 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 89/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0078 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8066 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 90/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0063 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8470 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 91/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7920 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 92/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8456 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 93/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0098 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7929 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 94/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0065 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8198 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 95/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0108 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.7891 - val_binary_accuracy: 0.8700 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 96/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0064 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8087 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 97/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8468 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 98/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0103 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8409 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 99/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0063 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7995 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 100/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0064 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8125 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 101/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0078 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8346 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 102/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0059 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8537 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 103/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0063 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8530 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 104/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0068 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8767 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 105/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0102 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.8632 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 106/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0081 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2112 - val_binary_accuracy: 0.7900 - val_precision: 0.7164 - val_recall: 0.9600
# Epoch 107/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8688 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 108/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8718 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 109/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8844 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 110/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0064 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9334 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 111/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8927 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 112/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9058 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 113/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0060 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8587 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 114/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0063 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9872 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 115/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8795 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 116/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9021 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 117/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9791 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 118/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8711 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 119/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8827 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 120/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0059 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9083 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 121/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8663 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 122/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0060 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8951 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 123/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8811 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 124/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0057 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8867 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 125/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9399 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 126/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8924 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 127/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9111 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 128/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0067 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9443 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 129/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0057 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8723 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 130/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0063 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9216 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 131/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0063 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9410 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 132/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0059 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8370 - val_binary_accuracy: 0.8600 - val_precision: 0.8462 - val_recall: 0.8800
# Epoch 133/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9498 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 134/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0060 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9069 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 135/200
# 200/200 [==============================] - 7s 33ms/step - loss: 0.0059 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8754 - val_binary_accuracy: 0.8900 - val_precision: 0.8545 - val_recall: 0.9400
# Epoch 136/200
# 200/200 [==============================] - 6s 32ms/step - loss: 0.0059 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9220 - val_binary_accuracy: 0.8800 - val_precision: 0.8276 - val_recall: 0.9600
# Epoch 137/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0098 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.9695 - val_binary_accuracy: 0.8500 - val_precision: 0.7966 - val_recall: 0.9400
# Epoch 138/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9839 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 139/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0070 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9343 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 140/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9711 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 141/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0064 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9489 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 142/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9633 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 143/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9229 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 144/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9618 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 145/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9897 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 146/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9836 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 147/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9487 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 148/200
# 200/200 [==============================] - 6s 28ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0043 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 149/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0061 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0852 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 150/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0268 - binary_accuracy: 0.9900 - precision: 0.9900 - recall: 0.9900 - val_loss: 1.0030 - val_binary_accuracy: 0.8500 - val_precision: 0.7966 - val_recall: 0.9400
# Epoch 151/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9241 - val_binary_accuracy: 0.8400 - val_precision: 0.7931 - val_recall: 0.9200
# Epoch 152/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0060 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9876 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 153/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9540 - val_binary_accuracy: 0.8500 - val_precision: 0.7966 - val_recall: 0.9400
# Epoch 154/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9962 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 155/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0057 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9593 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 156/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9203 - val_binary_accuracy: 0.8500 - val_precision: 0.8070 - val_recall: 0.9200
# Epoch 157/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0057 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9644 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 158/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9498 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 159/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0062 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9705 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 160/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9463 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 161/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0057 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9924 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 162/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9436 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 163/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9600 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 164/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9673 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 165/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9666 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 166/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9750 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 167/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9584 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 168/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9726 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 169/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9932 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 170/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9757 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 171/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9723 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 172/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9812 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 173/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9973 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 174/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9680 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 175/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0066 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9372 - val_binary_accuracy: 0.8600 - val_precision: 0.8214 - val_recall: 0.9200
# Epoch 176/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9872 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 177/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9849 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 178/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9702 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 179/200
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9854 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 180/200
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0111 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 0.9504 - val_binary_accuracy: 0.8500 - val_precision: 0.8182 - val_recall: 0.9000
# Epoch 181/200
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0058 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9839 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 182/200
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9914 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 183/200
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9853 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 184/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9734 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 185/200
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9935 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 186/200
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9731 - val_binary_accuracy: 0.8700 - val_precision: 0.8246 - val_recall: 0.9400
# Epoch 187/200
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9481 - val_binary_accuracy: 0.8600 - val_precision: 0.8333 - val_recall: 0.9000
# Epoch 188/200
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0102 - binary_accuracy: 0.9975 - precision: 1.0000 - recall: 0.9950 - val_loss: 1.0496 - val_binary_accuracy: 0.8300 - val_precision: 0.7619 - val_recall: 0.9600
# Epoch 189/200
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9454 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 190/200
# 200/200 [==============================] - 10s 51ms/step - loss: 0.0060 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9431 - val_binary_accuracy: 0.8800 - val_precision: 0.8393 - val_recall: 0.9400
# Epoch 191/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0157 - val_binary_accuracy: 0.8400 - val_precision: 0.7742 - val_recall: 0.9600
# Epoch 192/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9925 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 193/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9840 - val_binary_accuracy: 0.8700 - val_precision: 0.8136 - val_recall: 0.9600
# Epoch 194/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0056 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9712 - val_binary_accuracy: 0.8900 - val_precision: 0.8421 - val_recall: 0.9600
# Epoch 195/200
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0175 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 196/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0225 - val_binary_accuracy: 0.8600 - val_precision: 0.8000 - val_recall: 0.9600
# Epoch 197/200
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0266 - val_binary_accuracy: 0.8500 - val_precision: 0.7869 - val_recall: 0.9600
# Epoch 198/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0054 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9921 - val_binary_accuracy: 0.8600 - val_precision: 0.8103 - val_recall: 0.9400
# Epoch 199/200
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0030 - val_binary_accuracy: 0.8500 - val_precision: 0.7966 - val_recall: 0.9400
# Epoch 200/200
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0053 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9959 - val_binary_accuracy: 0.8500 - val_precision: 0.7966 - val_recall: 0.9400

# %% [markdown]
# Plot the loss and evaluation metrics:

# %%
from mlxtend.plotting import plot_decision_regions

history = hist.history

fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(2, 2, 1)
plt.plot(history['loss'], lw=4)
plt.plot(history['val_loss'], lw=4)
plt.legend(['Train loss', 'Validation loss'], fontsize=15)
ax.set_xlabel('Epochs', size=15)

ax = fig.add_subplot(2, 2, 2)
plt.plot(history['binary_accuracy'], lw=4)
plt.plot(history['val_binary_accuracy'], lw=4)
plt.legend(['Train Acc.', 'Validation Acc.'], fontsize=15)
ax.set_xlabel('Epochs', size=15)

ax = fig.add_subplot(2, 2, 3)
plt.plot(history['precision'], lw=4)
plt.plot(history['val_precision'], lw=4)
plt.legend(['Train Prec.', 'Validation Prec.'], fontsize=15)
ax.set_xlabel('Epochs', size=15)

ax = fig.add_subplot(2, 2, 4)
plt.plot(history['recall'], lw=4)
plt.plot(history['val_recall'], lw=4)
plt.legend(['Train Rec.', 'Validation Rec.'], fontsize=15)
ax.set_xlabel('Epochs', size=15)

plt.show()

# %% [markdown]
# ##### Final thoughts:
#
# The accuracy of our model started at 0.53 with our first attempt. After changing the learning rate and the regularization (L1) and adding additional dropout layers, we achieved 0.83 accuracy. There likely are some additional parameters that could be tuned more finely if we had more processing power available to us, but overall 0.83 is decent for our model. The plot of the loss is not what we expected; we expected the loss to decrease over the epochs for both train and validation, but we see the loss increase for validation. For the plots for accuracy, precision, and recall, the performance is generally better on the training set then the validation set; this suggests that our model is overfitting slightly to the training data. Overall, we think with further tuning and greater processing for faster model fitting, we could improve the performance, but 0.83 is a good accuracy.
